# %%
import requests
url = '	https://seat.tpml.edu.tw/sm/service/getAllArea'
response = requests.request('GET',url)
if response.status_code == 200:
    print("連線成功")
    all_data = response.json()
    print(type(all_data))
else:
    print(f"連線失敗:{response.status_code}")
# Out:
# 連線成功
# <class 'list'>

# %%
import pandas as pd

dataFrame = pd.DataFrame(data=all_data,columns=['sna','tot','sbi','sarea','mday','ar','bemp','act'])
dataFrame
# Out:
#                            sna  tot  sbi   sarea                 mday
# 0           YouBike2.0_捷運科技大樓站   28    1     大安區  2023-06-02 22:21:14  \
# 1       YouBike2.0_復興南路二段273號前   21    1     大安區  2023-06-02 22:11:14
# 2         YouBike2.0_國北教大實小東側門   16    4     大安區  2023-06-02 22:10:21
# 3            YouBike2.0_和平公園東側   11    1     大安區  2023-06-02 22:19:14
# 4         YouBike2.0_辛亥復興路口西北側   16    0     大安區  2023-06-02 22:21:14
# ...                        ...  ...  ...     ...                  ...
# 1276      YouBike2.0_臺大總圖書館西南側   30    0    臺大專區  2023-06-02 21:27:04
# 1277        YouBike2.0_臺大黑森林西側   20    0    臺大專區  2023-06-02 22:21:04
# 1278        YouBike2.0_臺大獸醫館南側   24    0    臺大專區  2023-06-02 21:49:04
# 1279      YouBike2.0_臺大新體育館東南側   40    0    臺大專區  2023-06-02 22:16:04
# 1280  YouBike2.0_臺大明達館北側(員工宿舍)   18    2  臺大公館校區  2023-06-02 22:09:15
#
#                  ar  bemp act
# 0       復興南路二段235號前    27   1
# 1      復興南路二段273號西側    20   1
# 2       和平東路二段96巷7號    12   1
# 3     和平東路二段118巷33號    10   1
# 4        復興南路二段368號    16   1
# ...             ...   ...  ..
# 1276       臺大圖書館西南側    30   1
# 1277        臺大霖澤館南側    20   1
# 1278       臺大獸醫系館南側    24   1
# 1279        臺大體育館東側    40   1
# 1280       明達館北側前空地    16   1
#
# [1281 rows x 8 columns]
