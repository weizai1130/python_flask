# %%
print("Hello! Python!")
# Out:
# Hello! Python!

# %%
#這是引數值
print(123,"我是int")
print(456.123,'我是float')
print("字串","這是str")
print(True,"我是bool值")
# Out:
# 123 我是int
# 456.123 我是float
# 字串 這是str
# True 我是bool值
# Bad pipe message: %s [b'\xd9\x83@\xe7q\xf6\xe7\xd9\xef6\x8e\xa6\xd5M\xcdYoE \xc0\xdc\xae\x1e\xfa\x17\x1f/\x92\xb6\xd9e\t/\xc3\x8c-w \xc2"\x92\xba\x91T\x9b\xc4\xe0V\xb85?\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00']
# Bad pipe message: %s [b'\x0c\x00\x00\t127.0.0.1']
# Bad pipe message: %s [b',{\xba\xdfis5\xd6[Z\xe4\xecb$u^\x83\x97 3OV\xb7\x8f\x9dC\x0b[u\xce\x12B\x1c\xff\xbb\xf7\x94\xeb\xd0\\[\x1d\xfd\xd5\xb6r\xac\xc6\x9e\x9c!\x00\x08\x13\x02\x13']
# ...
